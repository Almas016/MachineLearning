# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
covid = pd.read_csv('covid_impact_on_airport_traffic.csv')
covid
# Out:
#      AggregationMethod        Date  Version                    AirportName  \
# 0                Daily  2020-07-05      1.0                Kingsford Smith
# 1                Daily  2020-05-28      1.0                Kingsford Smith
# 2                Daily  2020-05-07      1.0                Kingsford Smith
# 3                Daily  2020-06-24      1.0                Kingsford Smith
# 4                Daily  2020-08-05      1.0                Kingsford Smith
# ...                ...         ...      ...                            ...
# 5931             Daily  2020-06-15      1.0  Seattle-Tacoma International
# 5932             Daily  2020-10-15      1.0  Seattle-Tacoma International
# 5933             Daily  2020-04-01      1.0  Seattle-Tacoma International
# 5934             Daily  2020-05-12      1.0  Seattle-Tacoma International
# 5935             Daily  2020-10-11      1.0  Seattle-Tacoma International
#
# ...

# %%
covid.describe()
# Out:
#        Version  PercentOfBaseline
# count   5936.0        5936.000000
# mean       1.0          65.581705
# std        0.0          21.985070
# min        1.0           0.000000
# 25%        1.0          52.000000
# 50%        1.0          66.000000
# 75%        1.0          82.000000
# max        1.0         100.000000

# %%
covid.duplicated().sum()
# Out:
# 0

# %%
covid.isnull().sum()
# Out:
# AggregationMethod    0
# Date                 0
# Version              0
# AirportName          0
# PercentOfBaseline    0
# Centroid             0
# City                 0
# State                0
# ISO_3166_2           0
# Country              0
# Geography            0
# dtype: int64

# %%
city_plot = covid['City'].value_counts().plot.bar()
city_plot

# %%
#for i in CITY
CityOne = covid[covid.City.isin(['New York'])]
CityOne.sort_values(by='Date').plot(x='Date',y='PercentOfBaseline',kind='area')

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5936 entries, 0 to 5935
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AggregationMethod  5936 non-null   object
#  1   Date               5936 non-null   object
#  2   Version            5936 non-null   float64
#  3   AirportName        5936 non-null   object
#  4   PercentOfBaseline  5936 non-null   int64
#  5   Centroid           5936 non-null   object
#  6   City               5936 non-null   object
#  7   State              5936 non-null   object
#  8   ISO_3166_2         5936 non-null   object
#  9   Country            5936 non-null   object
#  10  Geography          5936 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 510.2+ KB

# %%
import seaborn as sns
sns.distplot(covid['PercentOfBaseline'])

# %%
CountryPlot = covid['Country'].value_counts().plot(kind='pie',autopct = '%.2f',figsize=(12,12))

# %%
CityPlot = covid['City'].value_counts().plot(kind = 'pie',autopct = '%.5f',figsize=(12,12))

# %%
AirportNamePlot = covid['AirportName'].value_counts().plot(kind = 'pie',autopct = '%.5f',figsize=(8,8))
