# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('FinalData.csv')
data
# Out:
#                      City  Year        Shell  Volume  Mileage Transmission  \
# 0                 Уральск  2014  внедорожник     1.7    31000     механика
# 1     Нур-Султан (Астана)  2014        седан     3.5    59800      автомат
# 2                   Тараз  1995       фургон     2.3   450650     механика
# 3                  Алматы  2018        седан     2.5    48000    типтроник
# 4               Караганда  1997  внедорожник     3.5   153000      автомат
# ...                   ...   ...          ...     ...      ...          ...
# 7696            Экибастуз  2004      хэтчбек     1.6      286     механика
# 7697  Нур-Султан (Астана)  2015      лифтбек     2.0    62000     механика
# 7698               Атырау  2008        седан     2.0   146000     механика
# 7699  Нур-Султан (Астана)  2008    кроссовер     2.0   208500    типтроник
# 7700               Алматы  2017        седан     3.0    70000      автомат
#
# ...

# %%
def showpie(columnName):
    df_sym = pd.DataFrame(data[columnName].value_counts())
    df_sym.plot.pie(subplots=True,labels = df_sym.index.values, autopct='%1.1f%%', figsize = (15,10))
    # Unsquish the pie.
    plt.gca().set_aspect('equal')
    plt.show()
    plt.tight_layout()
    
showpie('Company')

# %%
data.loc[data['Company']=='Toyota','Model'].unique()
# Out:
# array(['Camry', 'Highlander', 'Tacoma', 'Corolla', 'Sequoia', 'Scepter',
#        'Hilux', 'Crown', 'Hilux Surf', 'Alphard', 'Yaris',
#        'Land Cruiser Prado', 'Altezza', 'Estima', 'Carina E', 'RAV 4',
#        'Mark II', 'Land Cruiser', 'Vista', 'Voxy', 'Matrix', 'Ipsum',
#        'Crown Majesta', 'Avensis', 'Mark X', 'Nadia', 'Camry Gracia',
#        'Sienna', 'HiAce Regius', 'Picnic', 'Tundra', 'Harrier', 'Granvia',
#        'Urban Cruiser', 'Aristo', 'Noah', 'Estima Lucida', 'C-HR',
#        'HiAce', 'Venza', 'Auris', 'Town Ace Noah', 'Corolla Verso',
#        'Avalon', 'FJ Cruiser', 'Soarer', 'Windom', 'Gaia', 'Cavalier',
#        '4Runner', 'Echo', 'Previa', 'Opa', 'Chaser', 'Caldina', 'Century',
#        'Prius', 'Starlet', 'Corona', 'Avensis Verso', 'Fortuner',
#        'Carina ED', 'Tercel', 'Cresta', 'Brevis', 'Carina', 'Wish',
#        'Cami', 'Vellfire', 'Isis', 'Camry Lumiere', 'Sprinter Carib',
#        'Vista Ardeo', 'Curren'], dtype=object)

# %%
data['Company'].value_counts()
# Out:
# Toyota              1529
# ВАЗ (Lada)          1061
# Mercedes-Benz        606
# Hyundai              427
# Nissan               423
#                     ...
# Lamborghini            1
# ВИС                    1
# ГАЗ 1998               1
# Mercedes-Maybach       1
# Alfa Romeo             1
# Name: Company, Length: 83, dtype: int64

# %%
data['Model'].value_counts()
# Out:
# Camry                 514
# 2114 (хэтчбек)        210
# Nexia                 156
# Land Cruiser          152
# Land Cruiser Prado    149
#                      ...
# LADA Priora             1
# Oley                    1
# FX45                    1
# C 36 AMG                1
# Town Ace Noah           1
# Name: Model, Length: 737, dtype: int64

# %%
data.loc[data['Company']=='ВАЗ (Lada)','Model'].value_counts()
# Out:
# 2114 (хэтчбек)         210
# 2170 (седан)           131
# 2115 (седан)            93
# 2190 (седан)            76
# 2107                    61
# 2121 Нива               57
# 2110 (седан)            53
# 2172 (хэтчбек)          50
# 2112 (хэтчбек)          41
# Largus                  35
# Vesta                   32
# 2171 (универсал)        32
# 21099 (седан)           27
# 2106                    22
# XRAY                    12
# 2194 (универсал)        12
# 2131 (5-ти дверный)     12
# 2109 (хэтчбек)          12
# 2113 (хэтчбек)          12
# 2191 (лифтбек)           9
# 2192 (хэтчбек)           8
# 2104                     7
# Largus Cross             7
# 1117 (универсал)         7
# 1118 (седан)             7
# 2105                     6
# 2111 (универсал)         5
# 1119 (хэтчбек)           5
# Largus (фургон)          4
# 2101                     3
# Vesta Cross              3
# 2108 (хэтчбек)           2
# 2123                     2
# 2329 (пикап)             1
# ...
