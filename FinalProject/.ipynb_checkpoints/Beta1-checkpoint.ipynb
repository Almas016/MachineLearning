# %%
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('FinalData.csv')

data.drop(data[data['Mileage'] >= 0.1 * 10**7].index, inplace=True)
data.drop(data[data['Price'] >= 0.2 * 10**8].index, inplace=True)
data.drop(data[data['Volume'] >= 4.7].index,inplace=True)
data.drop(data[data['Year'] <= 1985].index, inplace=True)

data.drop(data[data['Price'] >= 1.22 * 10**7].index, inplace=True)
data.drop(data[data['Mileage'] >= 0.48 * 10**6].index, inplace=True)
data.drop(data[(data['Volume'] >= 3.7) | (data['Volume'] < 0.3)].index,inplace=True)

data
# Out:
#                       City  Year        Shell  Volume  Mileage Transmission  \
# 0                  Уральск  2014  внедорожник     1.7    31000     механика
# 1      Нур-Султан (Астана)  2014        седан     3.5    59800      автомат
# 2                    Тараз  1995       фургон     2.3   450650     механика
# 3                   Алматы  2018        седан     2.5    48000    типтроник
# 4                Караганда  1997  внедорожник     3.5   153000      автомат
# ...                    ...   ...          ...     ...      ...          ...
# 16029                Тараз  1989        седан     2.0   338065     механика
# 16030             Костанай  2014        седан     1.6   160000     механика
# 16031               Сайхин  2008  внедорожник     1.8   175000     механика
# 16032  Нур-Султан (Астана)  2014        седан     1.5   103000     механика
# 16034  Нур-Султан (Астана)  1991        седан     2.3   241321     механика
#
#        Rudder             Gear CustomsCleared Type Engine        Company  \
# 0       слева    полный привод             Да      бензин      Chevrolet
# 1       слева  передний привод             Да      бензин            Kia
# 2       слева    задний привод             Да      дизель     Volkswagen
# 3       слева  передний привод             Да      бензин         Toyota
# 4      справа    полный привод            Нет      бензин     Mitsubishi
# ...       ...              ...            ...         ...            ...
# 16029   слева  передний привод             Да      бензин           Audi
# 16030   слева  передний привод            Нет      бензин         Datsun
# 16031   слева    полный привод             Да      бензин      Chevrolet
# 16032   слева  передний привод             Да      бензин         Daewoo
# 16034   слева    задний привод             Да      бензин  Mercedes-Benz
#
#          Model     Price
# 0         Niva   2900000
# 1      Cadenza   8600000
# 2           LT   1100000
# 3        Camry  11300000
# 4       Pajero   3350000
# ...        ...       ...
# 16029       80    570000
# 16030    on-DO   1550000
# 16031     Niva   1500000
# 16032   Gentra   3300000
# 16034    E 230   1400000
#
# [12838 rows x 13 columns]

# %%
df = data

# %%
df = df.append(pd.Series(['Уральск',1992,'седан',2.5,241321,'механика','слева','задний привод','Да','бензин','Mercedes-Benz','E 230',1400000], index=df.columns ), ignore_index=True)
df
# Out:
#                       City  Year        Shell  Volume  Mileage Transmission  \
# 0                  Уральск  2014  внедорожник     1.7    31000     механика
# 1      Нур-Султан (Астана)  2014        седан     3.5    59800      автомат
# 2                    Тараз  1995       фургон     2.3   450650     механика
# 3                   Алматы  2018        седан     2.5    48000    типтроник
# 4                Караганда  1997  внедорожник     3.5   153000      автомат
# ...                    ...   ...          ...     ...      ...          ...
# 12834             Костанай  2014        седан     1.6   160000     механика
# 12835               Сайхин  2008  внедорожник     1.8   175000     механика
# 12836  Нур-Султан (Астана)  2014        седан     1.5   103000     механика
# 12837  Нур-Султан (Астана)  1991        седан     2.3   241321     механика
# 12838              Уральск  1992        седан     2.5   241321     механика
#
#        Rudder             Gear CustomsCleared Type Engine        Company  \
# 0       слева    полный привод             Да      бензин      Chevrolet
# 1       слева  передний привод             Да      бензин            Kia
# 2       слева    задний привод             Да      дизель     Volkswagen
# 3       слева  передний привод             Да      бензин         Toyota
# 4      справа    полный привод            Нет      бензин     Mitsubishi
# ...       ...              ...            ...         ...            ...
# 12834   слева  передний привод            Нет      бензин         Datsun
# 12835   слева    полный привод             Да      бензин      Chevrolet
# 12836   слева  передний привод             Да      бензин         Daewoo
# 12837   слева    задний привод             Да      бензин  Mercedes-Benz
# 12838   слева    задний привод             Да      бензин  Mercedes-Benz
#
#          Model     Price
# 0         Niva   2900000
# 1      Cadenza   8600000
# 2           LT   1100000
# 3        Camry  11300000
# 4       Pajero   3350000
# ...        ...       ...
# 12834    on-DO   1550000
# 12835     Niva   1500000
# 12836   Gentra   3300000
# 12837    E 230   1400000
# 12838    E 230   1400000
#
# [12839 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12838 entries, 0 to 16034
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   City            12838 non-null  object
#  1   Year            12838 non-null  int64
#  2   Shell           12838 non-null  object
#  3   Volume          12838 non-null  float64
#  4   Mileage         12838 non-null  int64
#  5   Transmission    12838 non-null  object
#  6   Rudder          12838 non-null  object
#  7   Gear            12838 non-null  object
#  8   CustomsCleared  12838 non-null  object
#  9   Type Engine     12838 non-null  object
#  10  Company         12838 non-null  object
#  11  Model           12838 non-null  object
#  12  Price           12838 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 2.0+ MB
