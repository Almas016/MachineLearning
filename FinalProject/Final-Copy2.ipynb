# %%
#importing the libraries
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Reading and Understanding the Data

# %%
companies = data['Name'].unique()
copy_companies = []
for company in companies:
    for i in range(len(company)):
        if( company[i] == ')' and company[i+1]. )
# Out:
# array(['ChevroletNiva', 'KiaCadenza', 'VolkswagenLT', 'ToyotaCamry',
#        'MitsubishiPajero', 'LincolnNavigator', 'Mercedes-Benz 1995',
#        'ToyotaHighlander', 'HyundaiElantra', 'HyundaiAccent',
#        'ToyotaTacoma', 'OpelVectra', 'VolkswagenGolf',
#        'Mercedes-BenzE 200', 'VolkswagenPassat', 'ToyotaCorolla',
#        'ВАЗ (Lada)2172 (хэтчбек)', 'ToyotaSequoia',
#        'ВАЗ (Lada)2113 (хэтчбек)', 'BMW525', 'FordMustang',
#        'SubaruOutback', 'RenaultSandero Stepway', 'BMWX5',
#        'ToyotaScepter', 'ToyotaHilux', 'ГАЗГАЗель', 'BMW520',
#        'LexusGX 460', 'ToyotaCrown', 'VolkswagenTouareg',
#        'Mercedes-BenzE 280', 'SkodaYeti', 'HondaOdyssey',
#        'ВАЗ (Lada)2114 (хэтчбек)', 'KiaRio', 'NissanQashqai',
#        'LexusLX 470', 'ToyotaHilux Surf', 'KiaNiro', 'NissanTeana',
#        'FordFocus', 'ВАЗ (Lada)2190 (седан)', 'Mercedes-BenzG 240',
#        'GeelyEmgrand X7', 'ВАЗ (Lada)2171 (универсал)',
#        'VolkswagenSharan', 'LexusRX 300', 'MitsubishiPajero IO',
#        'Datsunon-DO', 'HummerH2', 'Mazda3', 'Mercedes-BenzE 320',
#        'ChevroletTracker', 'ВАЗ (Lada)2115 (седан)', 'Mercedes-BenzE 230',
#        'NissanPrimera', 'LexusLX 570', 'HondaCivic',
#        'ВАЗ (Lada)2170 (седан)', 'ВАЗ (Lada)Largus', 'Mercedes-Benz 2015',
#        'NissanSerena', 'VolkswagenBora', 'ToyotaAlphard', 'SubaruLegacy',
#        'Mercedes-BenzE 260', 'MitsubishiDelica', 'MitsubishiEclipse',
#        'DaewooNexia', 'ChevroletOrlando', 'Mazda6', 'FordMondeo',
#        'ChevroletCruze', 'KiaSportage', 'HyundaiAvante',
#        'Mercedes-BenzGLK 300', 'AudiA8', 'NissanJuke',
#        'Mercedes-BenzS 500', 'BMW328', 'ВАЗ (Lada)2121 Нива',
#        'Mercedes-BenzE 300', 'УАЗHunter', 'Mercedes-BenzS 63 AMG',
#        'LifanSmily', 'ToyotaYaris', 'ToyotaLand Cruiser Prado',
#        'NissanPatrol', 'KiaMorning', 'ВАЗ (Lada)2110 (седан)', 'FAWV5',
#        'RenaultDuster', 'ВАЗ (Lada)Vesta', 'LexusGS 350', 'LexusES 350',
#        'BMW318', 'BMW523', 'Mercedes-BenzE 350', 'ToyotaAltezza',
#        'InfinitiFX35', 'Land RoverRange Rover', 'VolkswagenPolo',
#        'SkodaFabia', 'NissanX-Trail', 'ВАЗ (Lada)21099 (седан)', 'Audi80',
#        'ЗАЗChance', 'ToyotaEstima', 'Mercedes-BenzC 240',
#        'SsangYongIstana', 'NissanPathfinder', 'Rover400 Series',
#        'ToyotaCarina E', 'LincolnTown Car', 'JACS3', 'BMW750',
#        'ToyotaRAV 4', 'PorscheCayenne', 'ToyotaMark II',
#        'Land RoverRange Rover Sport', 'LexusRX 350', 'ЗАЗVida',
#        'JeepGrand Cherokee', 'SubaruForester', 'ToyotaLand Cruiser',
#        'SubaruTribeca', 'Mercedes-BenzCL 500',
#        'Land RoverRange Rover Velar', 'ВАЗ (Lada)2107', 'Audi100',
#        'AudiA6', 'AudiA4', 'SkodaRapid', 'УАЗ3303', 'KiaStonic',
#        'ChevroletEpica', 'LexusNX 200', 'VolkswagenAmarok',
#        'Mercedes-BenzGLK 250', 'HondaCR-V', 'HondaElysion',
#        'Mercedes-BenzCLA 45 AMG', 'MazdaPremacy', 'Mercedes-BenzS 450',
#        'NissanMicra', 'LifanBreez', 'PorschePanamera',
#        'Mercedes-BenzV 220', 'NissanMaxima',
#        'ВАЗ (Lada)2131 (5-ти дверный)', 'HyundaiSonata', 'Chrysler300M',
#        'HyundaiTucson', 'FiatDucato', 'LexusRX 330', 'Mercedes-Benz190',
#        'KiaCerato', 'OpelCorsa', 'Mercedes-BenzML 63 AMG', 'УАЗPatriot',
#        'HyundaiGrandeur', 'Mercedes-BenzG 320', 'BMW528',
#        'Mercedes-Benz 2012', 'BMWX6', 'HyundaiCreta', 'NissanCefiro',
#        'MitsubishiSpace Wagon', 'BMWM3', 'Mazda323', 'JeepWrangler',
#        'ToyotaVista', 'KiaCee’d', 'LifanX60', 'ToyotaVoxy',
#        'MitsubishiLancer', 'Mercedes-Benz 1996', 'JeepGladiator',
#        'NissanFuga', 'Mercedes-BenzML 320', 'ToyotaMatrix', 'HyundaiGetz',
#        'Mercedes-BenzB 180', 'MitsubishiGalant', 'MitsubishiGrandis',
#        'KiaK5', 'Mercedes-BenzGL 450', 'Peugeot605', 'ToyotaIpsum',
#        'VolvoS60', 'ChevroletAveo', 'OpelFrontera', 'PorscheMacan',
#        'AudiQ7', 'ВАЗ (Lada)Vesta Cross', 'OpelAstra', 'LexusES 250',
#        'BMWX1', 'HyundaiStarex', 'Mercedes-BenzGL 500', 'LexusRX 400h',
#        'KiaSorento', 'ToyotaCrown Majesta', 'LexusLS 460', 'AudiA3',
#        'ToyotaAvensis', 'VolkswagenJetta', 'ВАЗ (Lada)2112 (хэтчбек)',
#        'Peugeot307', 'ChevroletCaptiva', 'Mercedes-BenzGLC 200',
#        'NissanAlmera', 'ГАЗ 2012', 'Peugeot206', 'AudiA5',
#        'Mercedes-BenzML 350', 'SubaruImpreza', 'KiaOptima', 'MazdaRX8',
#        'ToyotaMark X', 'Mercedes-BenzS 600', 'Mercedes-BenzC 180',
#        'BMW530', 'ChevroletLacetti', 'Mercedes-BenzG 55 AMG',
#        'ВАЗ (Lada)2192 (хэтчбек)', 'LifanSolano', 'FordFiesta', 'KiaSoul',
#        'ГАЗ3110 (Волга)', 'HyundaiSanta Fe', 'NissanCedric', 'NissanNote',
#        'MitsubishiOutlander', 'SkodaOctavia', 'AudiA6 allroad',
#        'NissanSentra', 'VolkswagenMultivan', 'MazdaCronos',
#        'DaewooGentra', 'ВАЗ (Lada)2191 (лифтбек)',
#        'Mercedes-BenzE 55 AMG', 'OpelSintra', 'FAWD60', 'InfinitiQ50',
#        'ВАЗ (Lada)2106', 'RenaultLogan', 'InfinitiQX56',
#        'Mercedes-BenzCLS 350', 'MitsubishiRVR', 'Mercedes-BenzA 200',
#        'MitsubishiAirtrek', 'LexusES 330', 'InfinitiG37', 'MazdaTribute',
#        'Peugeot407', 'HyundaiSolaris', 'ToyotaNadia', 'ВАЗ (Lada)2104',
#        'ChevroletSpark', 'ToyotaCamry Gracia', 'SuzukiSX4',
#        'RavonNexia R3', 'LexusGS 300', 'SkodaSuperb', 'ToyotaSienna',
#        'KiaCarnival', 'ГАЗГАЗель NEXT', 'VolkswagenTransporter',
#        'ToyotaHiAce Regius', 'MitsubishiCarisma', 'HondaStepwgn',
#        'ВАЗ (Lada)2109 (хэтчбек)', 'InfinitiQX60', 'Mazda626',
#        'Mercedes-BenzS 350', 'SsangYongKyron', 'ChevroletMalibu',
#        'AudiQ8', 'SuzukiGrand Vitara', 'ChevroletSilverado',
#        'Mercedes-BenzE 63 AMG', 'BMW630', 'Mercedes-BenzC 280',
#        'ToyotaPicnic', 'Mercedes-BenzS 560', 'Mercedes-BenzG 63 AMG',
#        'Mercedes-BenzC 200', 'Mercedes-BenzCLS 500', 'GenesisG70',
#        'NissanArmada', 'Mercedes-BenzA 180', 'KiaK7', 'HyundaiEquus',
#        'Mercedes-BenzS 320', 'RenaultSandero', 'ChevroletLanos',
#        'KiaCarens', 'ВАЗ (Lada)XRAY', 'MazdaMPV', 'ToyotaTundra',
#        'MiniCabrio', 'InfinitiQX80', 'JaguarXF', 'MitsubishiL200',
#        'УАЗPickup', 'BMW650', 'BMW728', 'MG5', 'LexusRX 270',
#        'Mercedes-BenzC 220', 'MazdaCX-7', 'HaimaM3', 'MitsubishiSigma',
#        'BMW540', 'RenaultTrafic', 'ГАЗ2410 (Волга)', 'LexusRX 200t',
#        'KiaCerato Koup', 'MitsubishiEclipse Cross', 'ToyotaHarrier',
#        'MitsubishiSpace Runner', 'Chrysler300C', 'ToyotaGranvia',
#        'NissanAltima', 'VolkswagenRoutan', 'BMW325',
#        'ВАЗ (Lada)2194 (универсал)', 'Peugeot2008',
#        'ВАЗ (Lada)1119 (хэтчбек)', 'ГАЗ3102 (Волга)',
#        'Mercedes-BenzV 250', 'DaewooNubira', 'FordGalaxy',
#        'Mercedes-BenzG 500', 'HondaLegend', 'Land RoverDiscovery',
#        'KiaPicanto', 'SubaruXV', 'RavonR4', 'Mercedes-BenzGL 550',
#        'SkodaKodiaq', 'RenaultSymbol', 'BMW330', 'Mercedes-BenzGL 63 AMG',
#        'Land RoverDefender', 'BMW316', 'BentleyBentayga', 'Peugeot508',
#        'MitsubishiDiamante', 'NissanMurano', 'NissanAlmera Classic',
#        'Land RoverRange Rover Evoque', 'FordTaurus', 'InfinitiQX50',
#        'GeelySC7', 'ToyotaUrban Cruiser', 'HondaPilot', 'ГАЗ 1998',
#        'Peugeot301', 'Mercedes-BenzC 320', 'GeelyGC6',
#        'ВАЗ (Lada)2111 (универсал)', 'Mercedes-BenzS 400', 'InfinitiQX70',
#        'Mercedes-BenzA 160', 'ВАЗ (Lada)Largus (фургон)',
#        'ВАЗ (Lada)1117 (универсал)', 'MazdaXedos 6', 'ToyotaAristo',
#        'Mercedes-BenzGLC 250', 'Peugeot406', 'FordEscape', 'ToyotaNoah',
#        'SuzukiXL7', 'VolkswagenCaddy', 'BMW735', 'HummerH1', 'NissanTino',
#        'LifanCebrium', 'УАЗБуханка', 'Mercedes-BenzViano', 'InfinitiFX37',
#        'SuzukiJimny', 'FordTransit', 'OpelMeriva', 'FordS-Max',
#        'VolkswagenCaravelle', 'MazdaSentia', 'ToyotaEstima Lucida',
#        'MitsubishiAspire', 'Mitsubishii', 'RavonR2', 'HondaInspire',
#        'FotonTunland', 'MitsubishiASX', 'ВАЗ (Lada)2123',
#        'ВАЗ (Lada)Нива', 'HondaAccord', 'ToyotaC-HR', 'NissanMarch',
#        'Rover600 Series', 'ToyotaHiAce', 'Lexus 2012', 'NissanNavara',
#        'HyundaiGenesis', 'MiniHatch', 'ToyotaVenza', 'LexusES 300',
#        'ToyotaAuris', 'SuzukiAlto', 'SsangYongKorando',
#        'ToyotaTown Ace Noah', 'BMW730', 'Mercedes-BenzE 240',
#        'SsangYongTivoli', 'Great WallVoleex C30',
#        'ВАЗ (Lada)1118 (седан)', 'NissanMistral', 'VolkswagenTiguan',
#        'NissanTerrano', 'RenaultKaptur', 'SubaruImpreza WRX STi',
#        'FiatPanda', 'LifanX70', 'Mercedes-BenzGLS 450', 'FordRanger',
#        'NissanNP300', 'ВАЗ (Lada)2101', 'AudiS4', 'VolkswagenPassat CC',
#        'Mercedes-BenzCLA 200', 'BMW740', 'ToyotaCorolla Verso',
#        'Mercedes-BenzGLA 200', 'AudiS8', 'VolkswagenTeramont',
#        'ToyotaAvalon', 'SubaruImpreza WRX', 'ВАЗ (Lada)Largus Cross',
#        'InfinitiM35', 'Land RoverFreelander', 'LexusES 200',
#        'LexusIS 250', 'Renault SamsungSM7', 'MaseratiQuattroporte',
#        'NissanTiida', 'Mercedes-Benz 2001', 'ГАЗ24 (Волга)', 'Hyundaii30',
#        'LexusNX 300', 'ToyotaFJ Cruiser', 'Mercedes-BenzCL 550',
#        'KiaBongo', 'Mercedes-BenzVito', 'Mercedes-BenzGLE Coupe 63 AMG',
#        'Mercedes-BenzAMG GT', 'LexusNX 200t', 'ГАЗ31105 (Волга)',
#        'MiniCountryman', 'BMWM760', 'MitsubishiDion', 'ChevroletSuburban',
#        'Mercedes-BenzGL 350', 'LexusLS 350', 'FordExpedition', 'CheryQQ',
#        'InfinitiFX50', 'Mercedes-BenzML 400', 'SsangYongRexton',
#        'OpelOmega', 'BMWX6 M', 'BentleyContinental Flying Spur',
#        'Mercedes-BenzGL 400', 'BentleyContinental GT', 'BMW320',
#        'Hyundaii40', 'ToyotaSoarer', 'InfinitiG35', 'CitroenC4',
#        'Mercedes-BenzC 300', 'ChryslerPT Cruiser', 'Mercedes-BenzS 260',
#        'Mercedes-BenzSL 560', 'CheryAmulet (A15)',
#        'MitsubishiPajero Sport', 'CheryTiggo 5', 'ToyotaWindom',
#        'LexusGX 470', 'KiaSpectra', 'ToyotaGaia',
#        'SsangYongActyon Sports', 'Mercedes-MaybachS 600',
#        'Mercedes-BenzGLA 45 AMG', 'Mercedes-BenzGLE 450', 'JaguarXJ',
#        'ToyotaCavalier', 'ИЖ2717', 'NissanAvenir', 'ТагАЗC10', 'HummerH3',
#        'Mercedes-BenzE 53 AMG', 'SuzukiVitara', 'InfinitiEX35',
#        'CadillacEscalade', 'ВАЗ (Lada)2105', 'DaewooEspero',
#        'RenaultMegane', 'Mercedes-BenzSprinter', 'FotonAlpha', 'BMWM5',
#        'Toyota4Runner', 'MitsubishiMontero Sport', 'HondaPrelude',
#        'Mercedes-BenzC 250', 'Mercedes-BenzE 400', 'OpelZafira', 'AudiTT',
#        'VolkswagenGolf Plus', 'HondaFit Aria', 'CheryFora',
#        'Mercedes-BenzS 550', 'GeelyMK', 'Mercedes-BenzE 220',
#        'ToyotaEcho', 'AudiA7', 'HyundaiH-1', 'MazdaCX-9', 'ToyotaPrevia',
#        'NissanGT-R', 'УАЗ3151', 'LexusLS 600h', 'OpelAntara',
#        'Mercedes-BenzC 230', 'LexusGS 450h', 'ToyotaOpa',
#        'Mercedes-BenzCLK 320', 'VolvoV70', 'Mercedes-BenzE 420',
#        'SubaruBRZ', 'FAWBesturn B70', 'LifanX50', 'OpelVivaro', 'BMW745',
#        'FordExplorer', 'VolkswagenTouran', 'BMWX5 M',
#        'Mercedes-BenzCLA 220', 'LexusUX 200', 'KiaQuoris',
#        'MaseratiGhibli', 'BMW116', 'FordFusion', 'NissanSkyline',
#        'Hyundaiix35', 'MazdaEunos 500', 'NissanElgrand', 'NissanQuest',
#        'BentleyMulsanne', 'BMW118', 'RenaultMaster', 'ChevroletCobalt',
#        'ToyotaChaser', 'ВАЗ (Lada)1922 Бронто', 'NissanTitan',
#        'SeatToledo', 'ChanganCS35', 'RenaultLaguna', 'Москвич412',
#        'ToyotaCaldina', 'ВАЗ (Lada)2108 (хэтчбек)', 'FordF-Series',
#        'RenaultKangoo', 'FAWBesturn B50', 'ToyotaCentury', 'BMWX7',
#        'LexusGS 250', 'ГАЗ2330 (Тигр)', 'Mercedes-BenzML 270',
#        'ChevroletTahoe', 'MitsubishiSpace Gear', 'DaewooMatiz',
#        'Mercedes-BenzE 430', 'SsangYongActyon', 'HondaIntegra',
#        'ГАЗ31029 (Волга)', 'Lexus 2003', 'VolkswagenCrafter',
#        'PorscheCayman', 'BMW535', 'Mercedes-BenzA 45 AMG',
#        'Mercedes-BenzCL 63 AMG', 'DodgeRam', 'MitsubishiGTO', 'AudiRS 7',
#        'NissanSafari', 'KiaMagentis', 'Mercedes-BenzSL 500', 'BMWX3',
#        'Great WallHover M4', 'GMCSavana', 'NissanLiberty', 'BMW640',
#        'Mercedes-BenzGLS 400', 'NissanSunny', 'InfinitiQ30',
#        'ChevroletExpress', 'Great WallWingle 5', 'FiatPunto', 'VolvoS80',
#        'ToyotaPrius', 'ChanganBenBen Mini', 'SuzukiLiana',
#        'VolkswagenScirocco', 'MazdaCX-5', 'Mercedes-BenzS 65 AMG',
#        'ZXLandmark', 'NissanBluebird', 'Mercedes-BenzCLS 63 AMG',
#        'SuzukiBaleno', 'LexusRX 450h', 'Mercedes-BenzCE 230',
#        'MazdaXedos 9', 'ToyotaStarlet', 'VolvoXC90', 'Peugeot308',
#        'DaewooTosca', 'InfinitiFX45', 'Mercedes-BenzE 500',
#        'LexusES 300h', 'LexusNX 300h', 'InfinitiQ70', 'FiatDoblo',
#        'BMW518', 'ВИС2345 (Жигули)', 'HondaInsight', 'Audi90', 'JACS5',
#        'ГАЗСоболь', 'Mercedes-BenzGLE Coupe 43 AMG', 'DaewooLeganza',
#        'MazdaBongo Friendee', 'DodgeCaravan', 'ВАЗ (Lada)2103',
#        'ToyotaCorona', 'ЗАЗForza', 'CherySweet (QQ)', 'CadillacSRX',
#        'NissanCube', 'PeugeotPartner', 'JaguarXJS', 'ГАЗ21 (Волга)',
#        'Mercedes-BenzC 36 AMG', 'FordMaverick', 'NissanUrvan',
#        'Mercedes-BenzB 200', 'ToyotaAvensis Verso', 'ToyotaFortuner',
#        'MazdaMX3', 'LexusLS 430', 'Renault SamsungQM6', 'ToyotaCarina ED',
#        'GeelyEmgrand EC7', 'BMW323', 'MitsubishiPajero Pinin',
#        'Mercedes-BenzS 280', 'Volvo850', 'MitsubishiMontero',
#        'RenaultArkana', 'LexusGS 460', 'HondaOrthia', 'NissanGloria',
#        'Mercedes-BenzSL 300', 'ВАЗ (Lada)LADA Priora',
#        'Mercedes-BenzSLK 230', 'CheryTiggo', 'CheryM11', 'BMW218',
#        'LexusRC 350', 'JACT6', 'BMW5-Series Gran Turismo', 'Peugeot4007',
#        'ToyotaTercel', 'Mercedes-BenzCLA 250', 'MazdaBongo', 'KiaShuma',
#        'JeepLiberty', 'RenaultScenic', 'SsangYongNomad',
#        'Mercedes-BenzS 420', 'ToyotaCresta', 'Mercedes-Benz 2017',
#        'Alfa RomeoGTV', 'KiaMohave', 'KiaRay', 'LamborghiniGallardo',
#        'Mercedes-Benz 2005', 'KiaVenga', 'Mazda5', 'Mercedes-BenzR 350',
#        'ChevroletNexia', 'AudiQ5', 'Peugeot107', 'ГАЗ 2006', 'BMWX4',
#        'VolkswagenPhaeton', 'AudiS5', 'MaseratiLevante', 'NissanPrairie',
#        'ToyotaBrevis', 'Mercedes-BenzE 250', 'VolvoXC70',
#        'VolkswagenVento', 'DodgeAvenger', 'HondaStream', 'CitroenDS5',
#        'BMW760', 'RenaultKoleos', 'FAW1024', 'HyundaiTerracan',
#        'DaewooTico', 'ЗАЗ968', 'FAW6371', 'SubaruWRX', 'HyundaiGalloper',
#        'ToyotaCarina', 'Mercedes-BenzB 170', 'HondaS-MX', 'BAWLuba',
#        'FordSierra', 'HyundaiSantamo', 'ToyotaWish', 'HondaCrossroad',
#        'ToyotaCami', 'ToyotaVellfire', 'ToyotaIsis', 'IsuzuBighorn',
#        'LifanCelliya', 'Mercedes-BenzSL 55 AMG', 'BMW 1993',
#        'ВАЗ (Lada)11113 Ока', 'ЛуАЗ969', 'ToyotaCamry Lumiere',
#        'HondaFreed', 'ToyotaSprinter Carib', 'Mercedes-BenzA 140',
#        'Maybach57', 'KiaOpirus', 'ВАЗ (Lada)2329 (пикап)', 'Hyundai 2009',
#        "NissanR'nessa", 'DaewooMagnus', 'NissanAD', 'FAWOley',
#        'ChanganEado', 'ToyotaVista Ardeo', 'MitsubishiLegnum',
#        'MazdaDemio', 'ToyotaCurren', 'MitsubishiChariot', 'GenesisG80'],
#       dtype=object)

# %%
data = pd.read_csv('newdata.csv')
data.head()
# Out:
#                   City              Name  Year        Shell  Volume  Mileage  \
# 0              Уральск     ChevroletNiva  2014  внедорожник     1.7    31000
# 1  Нур-Султан (Астана)        KiaCadenza  2014        седан     3.5    59800
# 2                Тараз      VolkswagenLT  1995       фургон     2.3   450650
# 3               Алматы       ToyotaCamry  2018        седан     2.5    48000
# 4            Караганда  MitsubishiPajero  1997  внедорожник     3.5   153000
#
#   Transmission  Rudder            Color             Gear CustomsCleared  \
# 0     механика   слева      серебристый    полный привод             Да
# 1      автомат   слева  черный металлик  передний привод             Да
# 2     механика   слева            белый    задний привод             Да
# 3    типтроник   слева            белый  передний привод             Да
# 4      автомат  справа            белый    полный привод            Нет
#
#   Type Engine     Price
# 0      бензин   2900000
# 1      бензин   8600000
# 2      дизель   1100000
# 3      бензин  11300000
# 4      бензин   3350000

# %%
#data['test'] = data['Name'].str.findall('[A-Z][^A-Z]*')
a = 'Acura* Alfa Romeo* Alpina* Aston Martin* Audi* Aurus* * * BAIC* BAW* BMW* BYD* Bentley* Brilliance* Bugatti* Buick* * C* Cadillac* ChangFeng* Changan* Chery* Chevrolet* Chrysler* Citroen* * D* Dacia* Daewoo* Daihatsu* Datsun* Derways* Dodge* DongFeng* * E* Eagle* * F* FAW* Ferrari* Fiat* Ford* Foton* * G* GAC* GMC* Geely* Genesis* Gonow* Great Wall* * H* Hafei* Haima* Haval* Honda* HuangHai* Hummer* Hyundai* * I* Infiniti* Iran Khodro* Isuzu* * J* JAC* JMC* Jaguar* Jeep* Jinbei* * K* Kia* * L* Lamborghini* Lancia* Land Rover* Lexus* Lifan* Lincoln* Lotus* Lucid* Luxgen* * M* MG* Maserati* Maybach* Mazda* Mercedes-Benz* Mercedes-Maybach* Mercury* Mini* Mitsubishi* * N* Nissan* * O* Oldsmobile* Opel* * P* Peugeot* Plymouth* Pontiac* Porsche* Puch* * R* Ravon* Renault* Renault Samsung* Rolls-Royce* Rover* * S* SEAT* Saab* Santana* Saturn* Scion* ShuangHuan* Skoda* Smart* Soueast* SsangYong* Subaru* Suzuki* * T* Tesla* Tianma* Tianye* Toyota* * V* Volkswagen* Volvo* * W* Wuling* * X* Xinkai* * Z* ZX* Zotye* ВАЗ (Lada)* ВИС*  ГАЗ* ЕрАЗ* ЗАЗ* ЗИЛ* ИЖ* ЛуАЗ* Москвич* РАФ * СМЗ * ТагАЗ * УАЗ'
a = a.split('* ')

# %%
b = a
for x in b:
    if( len(x) < 2 ):
        a.remove(x)

# %%
a
# Out:
# ['Acura',
#  'Alfa Romeo',
#  'Alpina',
#  'Aston Martin',
#  'Audi',
#  'Aurus',
#  'BAIC',
#  'BAW',
#  'BMW',
#  'BYD',
#  'Bentley',
#  'Brilliance',
#  'Bugatti',
#  'Buick',
#  'C',
#  'Cadillac',
#  'ChangFeng',
#  'Changan',
#  'Chery',
#  'Chevrolet',
#  'Chrysler',
#  'Citroen',
#  'D',
#  'Dacia',
#  'Daewoo',
#  'Daihatsu',
#  'Datsun',
#  'Derways',
#  'Dodge',
#  'DongFeng',
#  'E',
#  'Eagle',
#  'F',
#  'FAW',
#  'Ferrari',
#  'Fiat',
#  'Ford',
#  'Foton',
#  'G',
#  'GAC',
#  'GMC',
#  'Geely',
#  'Genesis',
#  'Gonow',
#  'Great Wall',
#  'H',
#  'Hafei',
#  'Haima',
#  'Haval',
#  'Honda',
#  'HuangHai',
#  'Hummer',
#  'Hyundai',
#  'I',
#  'Infiniti',
#  'Iran Khodro',
#  'Isuzu',
#  'J',
#  'JAC',
#  'JMC',
#  'Jaguar',
#  'Jeep',
#  'Jinbei',
#  'K',
#  'Kia',
#  'L',
#  'Lamborghini',
#  'Lancia',
#  'Land Rover',
#  'Lexus',
#  'Lifan',
#  'Lincoln',
#  'Lotus',
#  'Lucid',
#  'Luxgen',
#  'M',
#  'MG',
#  'Maserati',
#  'Maybach',
#  'Mazda',
#  'Mercedes-Benz',
#  'Mercedes-Maybach',
#  'Mercury',
#  'Mini',
#  'Mitsubishi',
#  'N',
#  'Nissan',
#  'O',
#  'Oldsmobile',
#  'Opel',
#  'P',
#  'Peugeot',
#  'Plymouth',
#  'Pontiac',
#  'Porsche',
#  'Puch',
#  'R',
#  'Ravon',
#  'Renault',
#  'Renault Samsung',
#  'Rolls-Royce',
#  'Rover',
#  'S',
#  'SEAT',
#  'Saab',
#  'Santana',
#  'Saturn',
#  'Scion',
#  'ShuangHuan',
#  'Skoda',
#  'Smart',
#  'Soueast',
#  'SsangYong',
#  'Subaru',
#  'Suzuki',
#  'T',
#  'Tesla',
#  'Tianma',
#  'Tianye',
#  'Toyota',
#  'V',
#  'Volkswagen',
#  'Volvo',
#  'W',
#  'Wuling',
#  'X',
#  'Xinkai',
#  '',
#  'Z',
#  'ZX',
#  'Zotye',
#  'ВАЗ (Lada)',
#  'ВИС',
#  ' ГАЗ',
#  'ЕрАЗ',
#  'ЗАЗ',
#  'ЗИЛ',
#  'ИЖ',
#  'ЛуАЗ',
#  'Москвич',
#  'РАФ ',
#  'СМЗ ',
#  'ТагАЗ ',
#  'УАЗ']

# %%
data['Company'] = data['Name']

# %%
for i in range(len(data['Name'])):
    for j in a:
        if data['Name'][i].find(j) != -1:
            data['Company'][i] = j
# Out:
# <ipython-input-7-5926dfe158ce>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Company'][i] = j

# %%
data['Model'] = data['Name']
for i in range(len(data['Name'])):
    data['Model'][i] = data['Name'][i].replace(data['Company'][i], "")
# Out:
# <ipython-input-79-e3e66a31b6d8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Model'][i] = data['Name'][i].replace(data['Company'][i], "")

# %%
data.drop('Name', axis = 1, inplace = True)

# %%
data.to_csv(r'FinalData.csv', index = False)

# %%
data = pd.read_csv('FinalData.csv')

# %%
data
# Out:
#                      City  Year        Shell  Volume  Mileage Transmission  \
# 0                 Уральск  2014  внедорожник     1.7    31000     механика
# 1     Нур-Султан (Астана)  2014        седан     3.5    59800      автомат
# 2                   Тараз  1995       фургон     2.3   450650     механика
# 3                  Алматы  2018        седан     2.5    48000    типтроник
# 4               Караганда  1997  внедорожник     3.5   153000      автомат
# ...                   ...   ...          ...     ...      ...          ...
# 7696            Экибастуз  2004      хэтчбек     1.6      286     механика
# 7697  Нур-Султан (Астана)  2015      лифтбек     2.0    62000     механика
# 7698               Атырау  2008        седан     2.0   146000     механика
# 7699  Нур-Султан (Астана)  2008    кроссовер     2.0   208500    типтроник
# 7700               Алматы  2017        седан     3.0    70000      автомат
#
#       Rudder                 Color             Gear CustomsCleared  \
# 0      слева           серебристый    полный привод             Да
# 1      слева       черный металлик  передний привод             Да
# 2      слева                 белый    задний привод             Да
# 3      слева                 белый  передний привод             Да
# 4     справа                 белый    полный привод            Нет
# ...      ...                   ...              ...            ...
# 7696   слева  серебристый металлик  передний привод            Нет
# 7697   слева        вишня металлик  передний привод             Да
# 7698   слева           серебристый  передний привод            Нет
# 7699   слева                черный    полный привод             Да
# 7700   слева                черный    полный привод             Да
#
#      Type Engine     Price     Company           Model
# 0         бензин   2900000   Chevrolet            Niva
# 1         бензин   8600000         Kia         Cadenza
# 2         дизель   1100000  Volkswagen              LT
# 3         бензин  11300000      Toyota           Camry
# 4         бензин   3350000  Mitsubishi          Pajero
# ...          ...       ...         ...             ...
# 7696      бензин    500000  ВАЗ (Lada)  2114 (хэтчбек)
# 7697      бензин   2250000  ВАЗ (Lada)  2191 (лифтбек)
# 7698      бензин   1400000     Hyundai          Sonata
# 7699      бензин   6200000        Audi              Q5
# 7700      бензин  13500000     Genesis             G80
#
# [7701 rows x 14 columns]
