# %% [markdown]
# Name: Namazbayev Almas

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %% [markdown]
# #### Load data

# %%
data = loadmat('ex7data1.mat')
X = data['X']

# %% [markdown]
# #### Plot data

# %%
dx, dy = X.T
plt.scatter(dx, dy)
plt.grid()

# %% [markdown]
# ### Write your own PCA algorithm

# %% [markdown]
# You need to find two principal components.
# You can use linear algebra libraries

# %% [markdown]
# If you are importing the PCA from sklearn, you get only 50%

# %%
def PCA(meanVector, eigenvectors):
    for i in eigenvectors: plt.annotate('', xy=(meanVector + i), xytext=meanVector, arrowprops=dict(width=1))
        
    plt.scatter(X[:, 0], X[:, 1])
    plt.grid()
    plt.show()
    
meanVector = np.mean(X, axis=0)
X -= meanVector
eigenvalue, eigenvectors = np.linalg.eig(np.cov(X.T))#covarianceMatrix

PCA(meanVector, eigenvectors.T)
PCA(meanVector, eigenvectors)

# %% [markdown]
# Your tasks are to draw two PCs and find orthogonal projections from some point to a given PCs.
